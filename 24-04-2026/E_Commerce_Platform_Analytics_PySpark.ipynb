# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL_Project_Lab").getOrCreate()

# %%
customers_csv = """customer_id,name,city,age,signup_date
1,Amit,Hyderabad,28,2023-01-10
2,Priya,Bangalore,32,2023-02-12
3,Rahul,Mumbai,29,2023-03-14
4,Sneha,Delhi,35,2023-04-15
5,Arjun,Chennai,27,2023-05-11
6,Meera,Hyderabad,31,2023-06-10
7,Karan,Pune,33,2023-06-22
8,Neha,Delhi,30,2023-07-10
9,Divya,Bangalore,26,2023-07-15
10,Vikram,Mumbai,40,2023-08-01
11,Ritu,Hyderabad,34,2023-08-10
12,Sanjay,Delhi,38,2023-08-21
13,Naveen,Chennai,28,2023-09-01
14,Farhan,Mumbai,36,2023-09-10
15,Simran,Bangalore,25,2023-09-18
"""

products_csv = """product_id,product_name,category,price
101,Laptop,Electronics,75000
102,Headphones,Electronics,3000
103,Keyboard,Electronics,1500
104,Monitor,Electronics,12000
105,Office Chair,Furniture,7000
106,Desk,Furniture,15000
107,Smartphone,Electronics,40000
108,Notebook,Stationery,100
109,Pen,Stationery,20
110,Tablet,Electronics,30000
"""

orders_csv = """order_id,customer_id,order_date,status
1,1,2024-03-01,Delivered
2,2,2024-03-02,Delivered
3,3,2024-03-03,Cancelled
4,4,2024-03-04,Delivered
5,5,2024-03-05,Delivered
6,6,2024-03-06,Delivered
7,7,2024-03-07,Pending
8,8,2024-03-08,Delivered
9,9,2024-03-09,Delivered
10,10,2024-03-10,Delivered
"""

order_items_csv = """order_id,product_id,quantity
1,101,1
1,102,2
2,103,1
3,101,1
4,104,1
5,107,1
6,102,3
7,103,2
8,110,1
9,108,5
10,109,10
"""

payments_csv = """payment_id,order_id,payment_type,amount
1,1,Credit Card,81000
2,2,UPI,1500
3,3,Debit Card,75000
4,4,Credit Card,12000
5,5,UPI,40000
6,6,UPI,9000
7,7,Debit Card,3000
8,8,Credit Card,30000
9,9,UPI,500
10,10,UPI,200
"""

logs_txt = """login Amit
login Priya
view Rahul
purchase Amit
view Sneha
login Amit
purchase Priya
view Arjun
purchase Sneha
login Rahul
logout Amit
login Neha
purchase Neha
view Vikram
purchase Vikram
login Farhan
view Farhan
purchase Farhan
login Simran
purchase Simran
"""

# %%
with open("customers.csv", "w") as f:
    f.write(customers_csv)

with open("products.csv", "w") as f:
    f.write(products_csv)

with open("orders.csv", "w") as f:
    f.write(orders_csv)

with open("order_items.csv", "w") as f:
    f.write(order_items_csv)

with open("payments.csv", "w") as f:
    f.write(payments_csv)

with open("logs.txt", "w") as f:
    f.write(logs_txt)

# %%
customers = spark.read.csv("customers.csv", header=True, inferSchema=True)
products = spark.read.csv("products.csv", header=True, inferSchema=True)
orders = spark.read.csv("orders.csv", header=True, inferSchema=True)
order_items = spark.read.csv("order_items.csv", header=True, inferSchema=True)
payments = spark.read.csv("payments.csv", header=True, inferSchema=True)

# %%
customers.show()
products.show()
orders.show()
order_items.show()
payments.show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+
#
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       102|  Headphones|Electronics| 3000|
# |       103|    Keyboard|Electronics| 1500|
# |       104|     Monitor|Electronics|12000|
# |       105|Office Chair|  Furniture| 7000|
# |       106|        Desk|  Furniture|15000|
# |       107|  Smartphone|Electronics|40000|
# |       108|    Notebook| Stationery|  100|
# |       109|         Pen| Stationery|   20|
# |       110|      Tablet|Electronics|30000|
# +----------+------------+-----------+-----+
#
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       3|          3|2024-03-03|Cancelled|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       7|          7|2024-03-07|  Pending|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+
#
# +--------+----------+--------+
# |order_id|product_id|quantity|
# +--------+----------+--------+
# |       1|       101|       1|
# |       1|       102|       2|
# |       2|       103|       1|
# |       3|       101|       1|
# |       4|       104|       1|
# |       5|       107|       1|
# |       6|       102|       3|
# |       7|       103|       2|
# |       8|       110|       1|
# |       9|       108|       5|
# |      10|       109|      10|
# +--------+----------+--------+
#
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         1|       1| Credit Card| 81000|
# |         2|       2|         UPI|  1500|
# |         3|       3|  Debit Card| 75000|
# |         4|       4| Credit Card| 12000|
# |         5|       5|         UPI| 40000|
# |         6|       6|         UPI|  9000|
# |         7|       7|  Debit Card|  3000|
# |         8|       8| Credit Card| 30000|
# |         9|       9|         UPI|   500|
# |        10|      10|         UPI|   200|
# +----------+--------+------------+------+

# %% [markdown]
# **Section 1 — DataFrame Basics**

# %%
# 1
customers.show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
# 2
customers.printSchema()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- signup_date: date (nullable = true)

# %%
# 3
customers.count()
# Out:
# 15

# %%
# 4
customers.show(5)
# Out:
# +-----------+-----+---------+---+-----------+
# |customer_id| name|     city|age|signup_date|
# +-----------+-----+---------+---+-----------+
# |          1| Amit|Hyderabad| 28| 2023-01-10|
# |          2|Priya|Bangalore| 32| 2023-02-12|
# |          3|Rahul|   Mumbai| 29| 2023-03-14|
# |          4|Sneha|    Delhi| 35| 2023-04-15|
# |          5|Arjun|  Chennai| 27| 2023-05-11|
# +-----------+-----+---------+---+-----------+
# only showing top 5 rows

# %%
# 5
customers.select("name", "city").show()
# Out:
# +------+---------+
# |  name|     city|
# +------+---------+
# |  Amit|Hyderabad|
# | Priya|Bangalore|
# | Rahul|   Mumbai|
# | Sneha|    Delhi|
# | Arjun|  Chennai|
# | Meera|Hyderabad|
# | Karan|     Pune|
# |  Neha|    Delhi|
# | Divya|Bangalore|
# |Vikram|   Mumbai|
# |  Ritu|Hyderabad|
# |Sanjay|    Delhi|
# |Naveen|  Chennai|
# |Farhan|   Mumbai|
# |Simran|Bangalore|
# +------+---------+

# %%
# 6
products.count()
# Out:
# 10

# %%
# 7
products.select("product_name", "price").show()
# Out:
# +------------+-----+
# |product_name|price|
# +------------+-----+
# |      Laptop|75000|
# |  Headphones| 3000|
# |    Keyboard| 1500|
# |     Monitor|12000|
# |Office Chair| 7000|
# |        Desk|15000|
# |  Smartphone|40000|
# |    Notebook|  100|
# |         Pen|   20|
# |      Tablet|30000|
# +------------+-----+

# %%
# 8
orders.show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       3|          3|2024-03-03|Cancelled|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       7|          7|2024-03-07|  Pending|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+

# %%
# 9
orders.count()
# Out:
# 10

# %%
# 10
payments.show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         1|       1| Credit Card| 81000|
# |         2|       2|         UPI|  1500|
# |         3|       3|  Debit Card| 75000|
# |         4|       4| Credit Card| 12000|
# |         5|       5|         UPI| 40000|
# |         6|       6|         UPI|  9000|
# |         7|       7|  Debit Card|  3000|
# |         8|       8| Credit Card| 30000|
# |         9|       9|         UPI|   500|
# |        10|      10|         UPI|   200|
# +----------+--------+------------+------+

# %% [markdown]
# **Section 2 — Filtering Data**

# %%
# 11
customers.filter(customers.city == "Hyderabad").show()
# Out:
# +-----------+-----+---------+---+-----------+
# |customer_id| name|     city|age|signup_date|
# +-----------+-----+---------+---+-----------+
# |          1| Amit|Hyderabad| 28| 2023-01-10|
# |          6|Meera|Hyderabad| 31| 2023-06-10|
# |         11| Ritu|Hyderabad| 34| 2023-08-10|
# +-----------+-----+---------+---+-----------+

# %%
# 12
customers.filter(customers.age > 30).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# +-----------+------+---------+---+-----------+

# %%
# 13
products.filter(products.price > 10000).show()
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       104|     Monitor|Electronics|12000|
# |       106|        Desk|  Furniture|15000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# +----------+------------+-----------+-----+

# %%
# 14
products.filter(products.category == "Electronics").show()
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       102|  Headphones|Electronics| 3000|
# |       103|    Keyboard|Electronics| 1500|
# |       104|     Monitor|Electronics|12000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# +----------+------------+-----------+-----+

# %%
# 15
orders.filter(orders.status == "Delivered").show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+

# %%
# 16
orders.filter(orders.status == "Cancelled").show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       3|          3|2024-03-03|Cancelled|
# +--------+-----------+----------+---------+

# %%
# 17
payments.filter(payments.payment_type == "UPI").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         2|       2|         UPI|  1500|
# |         5|       5|         UPI| 40000|
# |         6|       6|         UPI|  9000|
# |         9|       9|         UPI|   500|
# |        10|      10|         UPI|   200|
# +----------+--------+------------+------+

# %%
# 18
customers.filter(customers.city.isin("Bangalore", "Delhi")).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
# 19
products.filter(products.price < 1000).show()
# Out:
# +----------+------------+----------+-----+
# |product_id|product_name|  category|price|
# +----------+------------+----------+-----+
# |       108|    Notebook|Stationery|  100|
# |       109|         Pen|Stationery|   20|
# +----------+------------+----------+-----+

# %%
# 20
customers.filter(customers.age.between(25, 35)).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %% [markdown]
# **Section 3 — Selecting and Renaming**

# %%
# 21
products.withColumnRenamed("price", "product_price").show()
# Out:
# +----------+------------+-----------+-------------+
# |product_id|product_name|   category|product_price|
# +----------+------------+-----------+-------------+
# |       101|      Laptop|Electronics|        75000|
# |       102|  Headphones|Electronics|         3000|
# |       103|    Keyboard|Electronics|         1500|
# |       104|     Monitor|Electronics|        12000|
# |       105|Office Chair|  Furniture|         7000|
# |       106|        Desk|  Furniture|        15000|
# |       107|  Smartphone|Electronics|        40000|
# |       108|    Notebook| Stationery|          100|
# |       109|         Pen| Stationery|           20|
# |       110|      Tablet|Electronics|        30000|
# +----------+------------+-----------+-------------+

# %%
# 22
customers.withColumnRenamed("name", "customer_name").show()
# Out:
# +-----------+-------------+---------+---+-----------+
# |customer_id|customer_name|     city|age|signup_date|
# +-----------+-------------+---------+---+-----------+
# |          1|         Amit|Hyderabad| 28| 2023-01-10|
# |          2|        Priya|Bangalore| 32| 2023-02-12|
# |          3|        Rahul|   Mumbai| 29| 2023-03-14|
# |          4|        Sneha|    Delhi| 35| 2023-04-15|
# |          5|        Arjun|  Chennai| 27| 2023-05-11|
# |          6|        Meera|Hyderabad| 31| 2023-06-10|
# |          7|        Karan|     Pune| 33| 2023-06-22|
# |          8|         Neha|    Delhi| 30| 2023-07-10|
# |          9|        Divya|Bangalore| 26| 2023-07-15|
# |         10|       Vikram|   Mumbai| 40| 2023-08-01|
# |         11|         Ritu|Hyderabad| 34| 2023-08-10|
# |         12|       Sanjay|    Delhi| 38| 2023-08-21|
# |         13|       Naveen|  Chennai| 28| 2023-09-01|
# |         14|       Farhan|   Mumbai| 36| 2023-09-10|
# |         15|       Simran|Bangalore| 25| 2023-09-18|
# +-----------+-------------+---------+---+-----------+

# %%
# 23
customers.select("name", "age").show()
# Out:
# +------+---+
# |  name|age|
# +------+---+
# |  Amit| 28|
# | Priya| 32|
# | Rahul| 29|
# | Sneha| 35|
# | Arjun| 27|
# | Meera| 31|
# | Karan| 33|
# |  Neha| 30|
# | Divya| 26|
# |Vikram| 40|
# |  Ritu| 34|
# |Sanjay| 38|
# |Naveen| 28|
# |Farhan| 36|
# |Simran| 25|
# +------+---+

# %%
# 24
products.select("product_name", "category").show()
# Out:
# +------------+-----------+
# |product_name|   category|
# +------------+-----------+
# |      Laptop|Electronics|
# |  Headphones|Electronics|
# |    Keyboard|Electronics|
# |     Monitor|Electronics|
# |Office Chair|  Furniture|
# |        Desk|  Furniture|
# |  Smartphone|Electronics|
# |    Notebook| Stationery|
# |         Pen| Stationery|
# |      Tablet|Electronics|
# +------------+-----------+

# %%
# 25
orders.select("order_id", "order_date").show()
# Out:
# +--------+----------+
# |order_id|order_date|
# +--------+----------+
# |       1|2024-03-01|
# |       2|2024-03-02|
# |       3|2024-03-03|
# |       4|2024-03-04|
# |       5|2024-03-05|
# |       6|2024-03-06|
# |       7|2024-03-07|
# |       8|2024-03-08|
# |       9|2024-03-09|
# |      10|2024-03-10|
# +--------+----------+

# %%
# 26
payments.select("payment_type", "amount").show()
# Out:
# +------------+------+
# |payment_type|amount|
# +------------+------+
# | Credit Card| 81000|
# |         UPI|  1500|
# |  Debit Card| 75000|
# | Credit Card| 12000|
# |         UPI| 40000|
# |         UPI|  9000|
# |  Debit Card|  3000|
# | Credit Card| 30000|
# |         UPI|   500|
# |         UPI|   200|
# +------------+------+

# %%
# 27
products.withColumn("price_in_lakhs", products.price / 100000).show()
# Out:
# +----------+------------+-----------+-----+--------------+
# |product_id|product_name|   category|price|price_in_lakhs|
# +----------+------------+-----------+-----+--------------+
# |       101|      Laptop|Electronics|75000|          0.75|
# |       102|  Headphones|Electronics| 3000|          0.03|
# |       103|    Keyboard|Electronics| 1500|         0.015|
# |       104|     Monitor|Electronics|12000|          0.12|
# |       105|Office Chair|  Furniture| 7000|          0.07|
# |       106|        Desk|  Furniture|15000|          0.15|
# |       107|  Smartphone|Electronics|40000|           0.4|
# |       108|    Notebook| Stationery|  100|         0.001|
# |       109|         Pen| Stationery|   20|        2.0E-4|
# |       110|      Tablet|Electronics|30000|           0.3|
# +----------+------------+-----------+-----+--------------+

# %%
# 28
from pyspark.sql.functions import when

customers.withColumn(
    "age_group",
    when(customers.age < 30, "Young")
    .when(customers.age <= 35, "Adult")
    .otherwise("Senior")
).show()
# Out:
# +-----------+------+---------+---+-----------+---------+
# |customer_id|  name|     city|age|signup_date|age_group|
# +-----------+------+---------+---+-----------+---------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|    Young|
# |          2| Priya|Bangalore| 32| 2023-02-12|    Adult|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|    Young|
# |          4| Sneha|    Delhi| 35| 2023-04-15|    Adult|
# |          5| Arjun|  Chennai| 27| 2023-05-11|    Young|
# |          6| Meera|Hyderabad| 31| 2023-06-10|    Adult|
# |          7| Karan|     Pune| 33| 2023-06-22|    Adult|
# |          8|  Neha|    Delhi| 30| 2023-07-10|    Adult|
# |          9| Divya|Bangalore| 26| 2023-07-15|    Young|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|   Senior|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|    Adult|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|   Senior|
# |         13|Naveen|  Chennai| 28| 2023-09-01|    Young|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|   Senior|
# |         15|Simran|Bangalore| 25| 2023-09-18|    Young|
# +-----------+------+---------+---+-----------+---------+

# %%
# 29
order_items.filter(order_items.quantity > 2).show()
# Out:
# +--------+----------+--------+
# |order_id|product_id|quantity|
# +--------+----------+--------+
# |       6|       102|       3|
# |       9|       108|       5|
# |      10|       109|      10|
# +--------+----------+--------+

# %%
# 30
customers.orderBy("age").show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |         15|Simran|Bangalore| 25| 2023-09-18|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# +-----------+------+---------+---+-----------+

# %% [markdown]
# **Section 4 — Sorting and Limiting**

# %%
# 31
customers.orderBy("age").show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |         15|Simran|Bangalore| 25| 2023-09-18|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# +-----------+------+---------+---+-----------+

# %%
# 32
customers.orderBy(customers.age.desc()).show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
# 33
products.orderBy(products.price.desc()).show(5)
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# |       106|        Desk|  Furniture|15000|
# |       104|     Monitor|Electronics|12000|
# +----------+------------+-----------+-----+
# only showing top 5 rows

# %%
# 34
products.orderBy("price").show(3)
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       109|         Pen| Stationery|   20|
# |       108|    Notebook| Stationery|  100|
# |       103|    Keyboard|Electronics| 1500|
# +----------+------------+-----------+-----+
# only showing top 3 rows

# %%
# 35
orders.orderBy("order_date").show()
# Out:
# +--------+-----------+----------+---------+
# |order_id|customer_id|order_date|   status|
# +--------+-----------+----------+---------+
# |       1|          1|2024-03-01|Delivered|
# |       2|          2|2024-03-02|Delivered|
# |       3|          3|2024-03-03|Cancelled|
# |       4|          4|2024-03-04|Delivered|
# |       5|          5|2024-03-05|Delivered|
# |       6|          6|2024-03-06|Delivered|
# |       7|          7|2024-03-07|  Pending|
# |       8|          8|2024-03-08|Delivered|
# |       9|          9|2024-03-09|Delivered|
# |      10|         10|2024-03-10|Delivered|
# +--------+-----------+----------+---------+

# %%
# 36
payments.orderBy("amount").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |        10|      10|         UPI|   200|
# |         9|       9|         UPI|   500|
# |         2|       2|         UPI|  1500|
# |         7|       7|  Debit Card|  3000|
# |         6|       6|         UPI|  9000|
# |         4|       4| Credit Card| 12000|
# |         8|       8| Credit Card| 30000|
# |         5|       5|         UPI| 40000|
# |         3|       3|  Debit Card| 75000|
# |         1|       1| Credit Card| 81000|
# +----------+--------+------------+------+

# %%
# 37
payments.orderBy(payments.amount.desc()).show(3)
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |         1|       1| Credit Card| 81000|
# |         3|       3|  Debit Card| 75000|
# |         5|       5|         UPI| 40000|
# +----------+--------+------------+------+
# only showing top 3 rows

# %%
# 38
payments.orderBy("amount").show()
# Out:
# +----------+--------+------------+------+
# |payment_id|order_id|payment_type|amount|
# +----------+--------+------------+------+
# |        10|      10|         UPI|   200|
# |         9|       9|         UPI|   500|
# |         2|       2|         UPI|  1500|
# |         7|       7|  Debit Card|  3000|
# |         6|       6|         UPI|  9000|
# |         4|       4| Credit Card| 12000|
# |         8|       8| Credit Card| 30000|
# |         5|       5|         UPI| 40000|
# |         3|       3|  Debit Card| 75000|
# |         1|       1| Credit Card| 81000|
# +----------+--------+------------+------+

# %%
# 39
customers.orderBy("city").show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# +-----------+------+---------+---+-----------+

# %%
# 40
products.orderBy("category").show()
# Out:
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|price|
# +----------+------------+-----------+-----+
# |       101|      Laptop|Electronics|75000|
# |       102|  Headphones|Electronics| 3000|
# |       103|    Keyboard|Electronics| 1500|
# |       104|     Monitor|Electronics|12000|
# |       107|  Smartphone|Electronics|40000|
# |       110|      Tablet|Electronics|30000|
# |       105|Office Chair|  Furniture| 7000|
# |       106|        Desk|  Furniture|15000|
# |       108|    Notebook| Stationery|  100|
# |       109|         Pen| Stationery|   20|
# +----------+------------+-----------+-----+

# %% [markdown]
# **Section 5 — Aggregations**

# %%
from pyspark.sql.functions import sum, avg, max, min, count

# %%
# 41
payments.select(sum("amount")).show()
# Out:
# +-----------+
# |sum(amount)|
# +-----------+
# |     252200|
# +-----------+

# %%
# 42
payments.select(avg("amount")).show()
# Out:
# +-----------+
# |avg(amount)|
# +-----------+
# |    25220.0|
# +-----------+

# %%
# 43
payments.select(max("amount")).show()
# Out:
# +-----------+
# |max(amount)|
# +-----------+
# |      81000|
# +-----------+

# %%
# 44
payments.select(min("amount")).show()
# Out:
# +-----------+
# |min(amount)|
# +-----------+
# |        200|
# +-----------+

# %%
# 45
customers.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    3|
# |  Chennai|    2|
# |   Mumbai|    3|
# |     Pune|    1|
# |    Delhi|    3|
# |Hyderabad|    3|
# +---------+-----+

# %%
# 46
products.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# | Stationery|    2|
# |Electronics|    6|
# |  Furniture|    2|
# +-----------+-----+

# %%
# 47
products.groupBy("category").agg(avg("price")).show()
# Out:
# +-----------+------------------+
# |   category|        avg(price)|
# +-----------+------------------+
# | Stationery|              60.0|
# |Electronics|26916.666666666668|
# |  Furniture|           11000.0|
# +-----------+------------------+

# %%
# 48
order_items.groupBy("product_id").agg(sum("quantity")).show()
# Out:
# +----------+-------------+
# |product_id|sum(quantity)|
# +----------+-------------+
# |       108|            5|
# |       101|            2|
# |       103|            3|
# |       107|            1|
# |       102|            5|
# |       109|           10|
# |       110|            1|
# |       104|            1|
# +----------+-------------+

# %%
# 49
customers.select(avg("age")).show()
# Out:
# +------------------+
# |          avg(age)|
# +------------------+
# |31.466666666666665|
# +------------------+

# %%
# 50
orders.count()
# Out:
# 10

# %% [markdown]
# **Section 6 — Joins**

# %%
# 51
orders_customers = orders.join(customers, "customer_id")
orders_customers.show()
# Out:
# +-----------+--------+----------+---------+------+---------+---+-----------+
# |customer_id|order_id|order_date|   status|  name|     city|age|signup_date|
# +-----------+--------+----------+---------+------+---------+---+-----------+
# |          1|       1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|
# |          2|       2|2024-03-02|Delivered| Priya|Bangalore| 32| 2023-02-12|
# |          3|       3|2024-03-03|Cancelled| Rahul|   Mumbai| 29| 2023-03-14|
# |          4|       4|2024-03-04|Delivered| Sneha|    Delhi| 35| 2023-04-15|
# |          5|       5|2024-03-05|Delivered| Arjun|  Chennai| 27| 2023-05-11|
# |          6|       6|2024-03-06|Delivered| Meera|Hyderabad| 31| 2023-06-10|
# |          7|       7|2024-03-07|  Pending| Karan|     Pune| 33| 2023-06-22|
# |          8|       8|2024-03-08|Delivered|  Neha|    Delhi| 30| 2023-07-10|
# |          9|       9|2024-03-09|Delivered| Divya|Bangalore| 26| 2023-07-15|
# |         10|      10|2024-03-10|Delivered|Vikram|   Mumbai| 40| 2023-08-01|
# +-----------+--------+----------+---------+------+---------+---+-----------+

# %%
# 52
orders_customers.select("name", "status").show()
# Out:
# +------+---------+
# |  name|   status|
# +------+---------+
# |  Amit|Delivered|
# | Priya|Delivered|
# | Rahul|Cancelled|
# | Sneha|Delivered|
# | Arjun|Delivered|
# | Meera|Delivered|
# | Karan|  Pending|
# |  Neha|Delivered|
# | Divya|Delivered|
# |Vikram|Delivered|
# +------+---------+

# %%
# 53
orders_items = orders.join(order_items, "order_id")
orders_items.show()
# Out:
# +--------+-----------+----------+---------+----------+--------+
# |order_id|customer_id|order_date|   status|product_id|quantity|
# +--------+-----------+----------+---------+----------+--------+
# |       1|          1|2024-03-01|Delivered|       102|       2|
# |       1|          1|2024-03-01|Delivered|       101|       1|
# |       2|          2|2024-03-02|Delivered|       103|       1|
# |       3|          3|2024-03-03|Cancelled|       101|       1|
# |       4|          4|2024-03-04|Delivered|       104|       1|
# |       5|          5|2024-03-05|Delivered|       107|       1|
# |       6|          6|2024-03-06|Delivered|       102|       3|
# |       7|          7|2024-03-07|  Pending|       103|       2|
# |       8|          8|2024-03-08|Delivered|       110|       1|
# |       9|          9|2024-03-09|Delivered|       108|       5|
# |      10|         10|2024-03-10|Delivered|       109|      10|
# +--------+-----------+----------+---------+----------+--------+

# %%
# 54
items_products = order_items.join(products, "product_id")
items_products.show()
# Out:
# +----------+--------+--------+------------+-----------+-----+
# |product_id|order_id|quantity|product_name|   category|price|
# +----------+--------+--------+------------+-----------+-----+
# |       101|       3|       1|      Laptop|Electronics|75000|
# |       101|       1|       1|      Laptop|Electronics|75000|
# |       102|       6|       3|  Headphones|Electronics| 3000|
# |       102|       1|       2|  Headphones|Electronics| 3000|
# |       103|       7|       2|    Keyboard|Electronics| 1500|
# |       103|       2|       1|    Keyboard|Electronics| 1500|
# |       104|       4|       1|     Monitor|Electronics|12000|
# |       107|       5|       1|  Smartphone|Electronics|40000|
# |       108|       9|       5|    Notebook| Stationery|  100|
# |       109|      10|      10|         Pen| Stationery|   20|
# |       110|       8|       1|      Tablet|Electronics|30000|
# +----------+--------+--------+------------+-----------+-----+

# %%
# 55
items_products.withColumn("revenue", items_products.quantity * items_products.price).show()
# Out:
# +----------+--------+--------+------------+-----------+-----+-------+
# |product_id|order_id|quantity|product_name|   category|price|revenue|
# +----------+--------+--------+------------+-----------+-----+-------+
# |       101|       3|       1|      Laptop|Electronics|75000|  75000|
# |       101|       1|       1|      Laptop|Electronics|75000|  75000|
# |       102|       6|       3|  Headphones|Electronics| 3000|   9000|
# |       102|       1|       2|  Headphones|Electronics| 3000|   6000|
# |       103|       7|       2|    Keyboard|Electronics| 1500|   3000|
# |       103|       2|       1|    Keyboard|Electronics| 1500|   1500|
# |       104|       4|       1|     Monitor|Electronics|12000|  12000|
# |       107|       5|       1|  Smartphone|Electronics|40000|  40000|
# |       108|       9|       5|    Notebook| Stationery|  100|    500|
# |       109|      10|      10|         Pen| Stationery|   20|    200|
# |       110|       8|       1|      Tablet|Electronics|30000|  30000|
# +----------+--------+--------+------------+-----------+-----+-------+

# %%
# 56
full_df = orders.join(customers, "customer_id") \
                .join(order_items, "order_id") \
                .join(products, "product_id")

full_df.show()
# Out:
# +----------+--------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+
# |product_id|order_id|customer_id|order_date|   status|  name|     city|age|signup_date|quantity|product_name|   category|price|
# +----------+--------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+
# |       102|       1|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       2|  Headphones|Electronics| 3000|
# |       101|       1|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       1|      Laptop|Electronics|75000|
# |       103|       2|          2|2024-03-02|Delivered| Priya|Bangalore| 32| 2023-02-12|       1|    Keyboard|Electronics| 1500|
# |       101|       3|          3|2024-03-03|Cancelled| Rahul|   Mumbai| 29| 2023-03-14|       1|      Laptop|Electronics|75000|
# |       104|       4|          4|2024-03-04|Delivered| Sneha|    Delhi| 35| 2023-04-15|       1|     Monitor|Electronics|12000|
# |       107|       5|          5|2024-03-05|Delivered| Arjun|  Chennai| 27| 2023-05-11|       1|  Smartphone|Electronics|40000|
# |       102|       6|          6|2024-03-06|Delivered| Meera|Hyderabad| 31| 2023-06-10|       3|  Headphones|Electronics| 3000|
# |       103|       7|          7|2024-03-07|  Pending| Karan|     Pune| 33| 2023-06-22|       2|    Keyboard|Electronics| 1500|
# |       110|       8|          8|2024-03-08|Delivered|  Neha|    Delhi| 30| 2023-07-10|       1|      Tablet|Electronics|30000|
# |       108|       9|          9|2024-03-09|Delivered| Divya|Bangalore| 26| 2023-07-15|       5|    Notebook| Stationery|  100|
# |       109|      10|         10|2024-03-10|Delivered|Vikram|   Mumbai| 40| 2023-08-01|      10|         Pen| Stationery|   20|
# +----------+--------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+

# %%
# 57
full_df.select("name", "product_name", "quantity").show()
# Out:
# +------+------------+--------+
# |  name|product_name|quantity|
# +------+------------+--------+
# |  Amit|  Headphones|       2|
# |  Amit|      Laptop|       1|
# | Priya|    Keyboard|       1|
# | Rahul|      Laptop|       1|
# | Sneha|     Monitor|       1|
# | Arjun|  Smartphone|       1|
# | Meera|  Headphones|       3|
# | Karan|    Keyboard|       2|
# |  Neha|      Tablet|       1|
# | Divya|    Notebook|       5|
# |Vikram|         Pen|      10|
# +------+------------+--------+

# %%
# 58
full_df.withColumn("revenue", full_df.quantity * full_df.price) \
       .groupBy("order_id") \
       .agg(sum("revenue")) \
       .show()
# Out:
# +--------+------------+
# |order_id|sum(revenue)|
# +--------+------------+
# |       1|       81000|
# |       6|        9000|
# |       3|       75000|
# |       5|       40000|
# |       9|         500|
# |       4|       12000|
# |       8|       30000|
# |       7|        3000|
# |      10|         200|
# |       2|        1500|
# +--------+------------+

# %%
# 59
full_df.withColumn("revenue", full_df.quantity * full_df.price) \
       .groupBy("product_name") \
       .agg(sum("revenue")) \
       .show()
# Out:
# +------------+------------+
# |product_name|sum(revenue)|
# +------------+------------+
# |         Pen|         200|
# |      Laptop|      150000|
# |    Notebook|         500|
# |      Tablet|       30000|
# |    Keyboard|        4500|
# |  Smartphone|       40000|
# |     Monitor|       12000|
# |  Headphones|       15000|
# +------------+------------+

# %%
# 60
full_df.withColumn("revenue", full_df.quantity * full_df.price) \
       .groupBy("name") \
       .agg(sum("revenue")) \
       .show()
# Out:
# +------+------------+
# |  name|sum(revenue)|
# +------+------------+
# | Divya|         500|
# | Meera|        9000|
# | Sneha|       12000|
# | Priya|        1500|
# |Vikram|         200|
# | Rahul|       75000|
# | Arjun|       40000|
# |  Amit|       81000|
# |  Neha|       30000|
# | Karan|        3000|
# +------+------------+

# %% [markdown]
# **Section 7 — GroupBy Analytics**

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

sales_df = orders.join(customers, "customer_id") \
                 .join(order_items, "order_id") \
                 .join(products, "product_id") \
                 .withColumn("revenue", col("quantity") * col("price"))

# %%
# 61
orders.groupBy("customer_id").count().show()
# Out:
# +-----------+-----+
# |customer_id|count|
# +-----------+-----+
# |          1|    1|
# |          6|    1|
# |          3|    1|
# |          5|    1|
# |          9|    1|
# |          4|    1|
# |          8|    1|
# |          7|    1|
# |         10|    1|
# |          2|    1|
# +-----------+-----+

# %%
# 62.
orders.join(customers, "customer_id") \
      .groupBy("city") \
      .count() \
      .show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |     Pune|    1|
# |    Delhi|    2|
# |Hyderabad|    2|
# +---------+-----+

# %%
# 63.
sales_df.groupBy("product_name") \
        .agg(sum("revenue").alias("revenue")) \
        .show()
# Out:
# +------------+-------+
# |product_name|revenue|
# +------------+-------+
# |         Pen|    200|
# |      Laptop| 150000|
# |    Notebook|    500|
# |      Tablet|  30000|
# |    Keyboard|   4500|
# |  Smartphone|  40000|
# |     Monitor|  12000|
# |  Headphones|  15000|
# +------------+-------+

# %%
# 64
sales_df.groupBy("category") \
        .agg(sum("revenue").alias("revenue")) \
        .show()
# Out:
# +-----------+-------+
# |   category|revenue|
# +-----------+-------+
# | Stationery|    700|
# |Electronics| 251500|
# +-----------+-------+

# %%
# 65
sales_df.groupBy("city") \
        .agg(sum("revenue").alias("revenue")) \
        .show()
# Out:
# +---------+-------+
# |     city|revenue|
# +---------+-------+
# |Bangalore|   2000|
# |  Chennai|  40000|
# |   Mumbai|  75200|
# |     Pune|   3000|
# |    Delhi|  42000|
# |Hyderabad|  90000|
# +---------+-------+

# %%
# 66
sales_df.groupBy("product_name") \
        .agg(sum("quantity").alias("total_quantity")) \
        .show()
# Out:
# +------------+--------------+
# |product_name|total_quantity|
# +------------+--------------+
# |         Pen|            10|
# |      Laptop|             2|
# |    Notebook|             5|
# |      Tablet|             1|
# |    Keyboard|             3|
# |  Smartphone|             1|
# |     Monitor|             1|
# |  Headphones|             5|
# +------------+--------------+

# %%
# 67
sales_df.groupBy("category") \
        .agg(sum("quantity").alias("total_quantity")) \
        .show()
# Out:
# +-----------+--------------+
# |   category|total_quantity|
# +-----------+--------------+
# | Stationery|            15|
# |Electronics|            13|
# +-----------+--------------+

# %%
# 68
sales_df.groupBy("name") \
        .agg(sum("revenue").alias("revenue")) \
        .show()
# Out:
# +------+-------+
# |  name|revenue|
# +------+-------+
# | Divya|    500|
# | Meera|   9000|
# | Sneha|  12000|
# | Priya|   1500|
# |Vikram|    200|
# | Rahul|  75000|
# | Arjun|  40000|
# |  Amit|  81000|
# |  Neha|  30000|
# | Karan|   3000|
# +------+-------+

# %%
# 69
sales_df.groupBy("name") \
        .agg(sum("revenue").alias("revenue")) \
        .orderBy(col("revenue").desc()) \
        .show(5)
# Out:
# +-----+-------+
# | name|revenue|
# +-----+-------+
# | Amit|  81000|
# |Rahul|  75000|
# |Arjun|  40000|
# | Neha|  30000|
# |Sneha|  12000|
# +-----+-------+
# only showing top 5 rows

# %%
# 70
sales_df.groupBy("product_name") \
        .agg(sum("revenue").alias("revenue")) \
        .orderBy(col("revenue").desc()) \
        .show(3)
# Out:
# +------------+-------+
# |product_name|revenue|
# +------------+-------+
# |      Laptop| 150000|
# |  Smartphone|  40000|
# |      Tablet|  30000|
# +------------+-------+
# only showing top 3 rows

# %% [markdown]
# **Section 8 — Window Functions**

# %%
# 71
w1 = Window.orderBy(col("price").desc())

products.withColumn("rank", rank().over(w1)).show()
# Out:
# +----------+------------+-----------+-----+----+
# |product_id|product_name|   category|price|rank|
# +----------+------------+-----------+-----+----+
# |       101|      Laptop|Electronics|75000|   1|
# |       107|  Smartphone|Electronics|40000|   2|
# |       110|      Tablet|Electronics|30000|   3|
# |       106|        Desk|  Furniture|15000|   4|
# |       104|     Monitor|Electronics|12000|   5|
# |       105|Office Chair|  Furniture| 7000|   6|
# |       102|  Headphones|Electronics| 3000|   7|
# |       103|    Keyboard|Electronics| 1500|   8|
# |       108|    Notebook| Stationery|  100|   9|
# |       109|         Pen| Stationery|   20|  10|
# +----------+------------+-----------+-----+----+

# %%
# 72
w2 = Window.partitionBy("category").orderBy(col("price").desc())

products.withColumn("rank", rank().over(w2)).show()
# Out:
# +----------+------------+-----------+-----+----+
# |product_id|product_name|   category|price|rank|
# +----------+------------+-----------+-----+----+
# |       101|      Laptop|Electronics|75000|   1|
# |       107|  Smartphone|Electronics|40000|   2|
# |       110|      Tablet|Electronics|30000|   3|
# |       104|     Monitor|Electronics|12000|   4|
# |       102|  Headphones|Electronics| 3000|   5|
# |       103|    Keyboard|Electronics| 1500|   6|
# |       106|        Desk|  Furniture|15000|   1|
# |       105|Office Chair|  Furniture| 7000|   2|
# |       108|    Notebook| Stationery|  100|   1|
# |       109|         Pen| Stationery|   20|   2|
# +----------+------------+-----------+-----+----+

# %%
# 73
w3 = Window.orderBy("signup_date")

customers.withColumn("row_number", row_number().over(w3)).show()
# Out:
# +-----------+------+---------+---+-----------+----------+
# |customer_id|  name|     city|age|signup_date|row_number|
# +-----------+------+---------+---+-----------+----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|         1|
# |          2| Priya|Bangalore| 32| 2023-02-12|         2|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|         3|
# |          4| Sneha|    Delhi| 35| 2023-04-15|         4|
# |          5| Arjun|  Chennai| 27| 2023-05-11|         5|
# |          6| Meera|Hyderabad| 31| 2023-06-10|         6|
# |          7| Karan|     Pune| 33| 2023-06-22|         7|
# |          8|  Neha|    Delhi| 30| 2023-07-10|         8|
# |          9| Divya|Bangalore| 26| 2023-07-15|         9|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|        10|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|        11|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|        12|
# |         13|Naveen|  Chennai| 28| 2023-09-01|        13|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|        14|
# |         15|Simran|Bangalore| 25| 2023-09-18|        15|
# +-----------+------+---------+---+-----------+----------+

# %%
# 74
customer_revenue = sales_df.groupBy("name", "city") \
                           .agg(sum("revenue").alias("revenue"))

w4 = Window.orderBy(col("revenue").desc())

customer_revenue.withColumn("rank", rank().over(w4)).show()
# Out:
# +------+---------+-------+----+
# |  name|     city|revenue|rank|
# +------+---------+-------+----+
# |  Amit|Hyderabad|  81000|   1|
# | Rahul|   Mumbai|  75000|   2|
# | Arjun|  Chennai|  40000|   3|
# |  Neha|    Delhi|  30000|   4|
# | Sneha|    Delhi|  12000|   5|
# | Meera|Hyderabad|   9000|   6|
# | Karan|     Pune|   3000|   7|
# | Priya|Bangalore|   1500|   8|
# | Divya|Bangalore|    500|   9|
# |Vikram|   Mumbai|    200|  10|
# +------+---------+-------+----+

# %%
# 75
customer_revenue.withColumn("dense_rank", dense_rank().over(w4)).show()
# Out:
# +------+---------+-------+----------+
# |  name|     city|revenue|dense_rank|
# +------+---------+-------+----------+
# |  Amit|Hyderabad|  81000|         1|
# | Rahul|   Mumbai|  75000|         2|
# | Arjun|  Chennai|  40000|         3|
# |  Neha|    Delhi|  30000|         4|
# | Sneha|    Delhi|  12000|         5|
# | Meera|Hyderabad|   9000|         6|
# | Karan|     Pune|   3000|         7|
# | Priya|Bangalore|   1500|         8|
# | Divya|Bangalore|    500|         9|
# |Vikram|   Mumbai|    200|        10|
# +------+---------+-------+----------+

# %%
# 76
w5 = Window.partitionBy("city").orderBy(col("revenue").desc())

customer_revenue.withColumn("rank", rank().over(w5)) \
                .filter(col("rank") == 1) \
                .show()
# Out:
# +-----+---------+-------+----+
# | name|     city|revenue|rank|
# +-----+---------+-------+----+
# |Priya|Bangalore|   1500|   1|
# |Arjun|  Chennai|  40000|   1|
# | Neha|    Delhi|  30000|   1|
# | Amit|Hyderabad|  81000|   1|
# |Rahul|   Mumbai|  75000|   1|
# |Karan|     Pune|   3000|   1|
# +-----+---------+-------+----+

# %%
# 77
product_revenue = sales_df.groupBy("product_name", "category") \
                          .agg(sum("revenue").alias("revenue"))

w6 = Window.partitionBy("category").orderBy(col("revenue").desc())

product_revenue.withColumn("rank", rank().over(w6)) \
               .filter(col("rank") == 1) \
               .show()
# Out:
# +------------+-----------+-------+----+
# |product_name|   category|revenue|rank|
# +------------+-----------+-------+----+
# |      Laptop|Electronics| 150000|   1|
# |    Notebook| Stationery|    500|   1|
# +------------+-----------+-------+----+

# %%
# 78
order_revenue = sales_df.groupBy("order_id", "order_date") \
                        .agg(sum("revenue").alias("revenue"))

w7 = Window.orderBy("order_date")

order_revenue.withColumn(
    "running_total",
    sum("revenue").over(w7)
).show()
# Out:
# +--------+----------+-------+-------------+
# |order_id|order_date|revenue|running_total|
# +--------+----------+-------+-------------+
# |       1|2024-03-01|  81000|        81000|
# |       2|2024-03-02|   1500|        82500|
# |       3|2024-03-03|  75000|       157500|
# |       4|2024-03-04|  12000|       169500|
# |       5|2024-03-05|  40000|       209500|
# |       6|2024-03-06|   9000|       218500|
# |       7|2024-03-07|   3000|       221500|
# |       8|2024-03-08|  30000|       251500|
# |       9|2024-03-09|    500|       252000|
# |      10|2024-03-10|    200|       252200|
# +--------+----------+-------+-------------+

# %%
# 79
product_revenue = sales_df.groupBy("product_name") \
                          .agg(sum("revenue").alias("revenue"))

w8 = Window.orderBy(col("revenue").desc())

product_revenue.withColumn(
    "running_total",
    sum("revenue").over(w8)
).show()
# Out:
# +------------+-------+-------------+
# |product_name|revenue|running_total|
# +------------+-------+-------------+
# |      Laptop| 150000|       150000|
# |  Smartphone|  40000|       190000|
# |      Tablet|  30000|       220000|
# |  Headphones|  15000|       235000|
# |     Monitor|  12000|       247000|
# |    Keyboard|   4500|       251500|
# |    Notebook|    500|       252000|
# |         Pen|    200|       252200|
# +------------+-------+-------------+

# %%
# 80
w9 = Window.orderBy(col("amount").desc())

payments.withColumn("rank", rank().over(w9)).show()
# Out:
# +----------+--------+------------+------+----+
# |payment_id|order_id|payment_type|amount|rank|
# +----------+--------+------------+------+----+
# |         1|       1| Credit Card| 81000|   1|
# |         3|       3|  Debit Card| 75000|   2|
# |         5|       5|         UPI| 40000|   3|
# |         8|       8| Credit Card| 30000|   4|
# |         4|       4| Credit Card| 12000|   5|
# |         6|       6|         UPI|  9000|   6|
# |         7|       7|  Debit Card|  3000|   7|
# |         2|       2|         UPI|  1500|   8|
# |         9|       9|         UPI|   500|   9|
# |        10|      10|         UPI|   200|  10|
# +----------+--------+------------+------+----+

# %% [markdown]
# **Section 9 — RDD Exercises**

# %%
logs = spark.sparkContext.textFile("logs.txt")

# %%
# 81
logs.count()
# Out:
# 20

# %%
# 82
logs.map(lambda x: x.split()[1]).collect()
# Out:
# ['Amit',
#  'Priya',
#  'Rahul',
#  'Amit',
#  'Sneha',
#  'Amit',
#  'Priya',
#  'Arjun',
#  'Sneha',
#  'Rahul',
#  'Amit',
#  'Neha',
#  'Neha',
#  'Vikram',
#  'Vikram',
#  'Farhan',
#  'Farhan',
#  'Farhan',
#  'Simran',
#  'Simran']

# %%
# 83
logs.map(lambda x: x.split()[0]).collect()
# Out:
# ['login',
#  'login',
#  'view',
#  'purchase',
#  'view',
#  'login',
#  'purchase',
#  'view',
#  'purchase',
#  'login',
#  'logout',
#  'login',
#  'purchase',
#  'view',
#  'purchase',
#  'login',
#  'view',
#  'purchase',
#  'login',
#  'purchase']

# %%
# 84
logs.map(lambda x: x.split()[1]).distinct().collect()
# Out:
# ['Amit',
#  'Vikram',
#  'Simran',
#  'Priya',
#  'Rahul',
#  'Sneha',
#  'Arjun',
#  'Neha',
#  'Farhan']

# %%
# 85
logs.filter(lambda x: x.split()[0] == "login").count()
# Out:
# 7

# %%
# 86
logs.filter(lambda x: x.split()[0] == "purchase").count()
# Out:
# 7

# %%
# 87
logs.filter(lambda x: x.split()[0] == "view").count()
# Out:
# 5

# %%
# 88
pairs = logs.map(lambda x: (x.split()[1], 1))
pairs.collect()
# Out:
# [('Amit', 1),
#  ('Priya', 1),
#  ('Rahul', 1),
#  ('Amit', 1),
#  ('Sneha', 1),
#  ('Amit', 1),
#  ('Priya', 1),
#  ('Arjun', 1),
#  ('Sneha', 1),
#  ('Rahul', 1),
#  ('Amit', 1),
#  ('Neha', 1),
#  ('Neha', 1),
#  ('Vikram', 1),
#  ('Vikram', 1),
#  ('Farhan', 1),
#  ('Farhan', 1),
#  ('Farhan', 1),
#  ('Simran', 1),
#  ('Simran', 1)]

# %%
# 89
activity_count = pairs.reduceByKey(lambda a, b: a + b)
activity_count.collect()
# Out:
# [('Amit', 4),
#  ('Vikram', 2),
#  ('Simran', 2),
#  ('Priya', 2),
#  ('Rahul', 2),
#  ('Sneha', 2),
#  ('Arjun', 1),
#  ('Neha', 2),
#  ('Farhan', 3)]

# %%
# 90
activity_count.sortBy(lambda x: x[1], ascending=False).take(1)
# Out:
# [('Amit', 4)]

# %% [markdown]
# **Section 10 — Spark SQL**

# %%
#Temp view

customers.createOrReplaceTempView("customers")
orders.createOrReplaceTempView("orders")
products.createOrReplaceTempView("products")
payments.createOrReplaceTempView("payments")
order_items.createOrReplaceTempView("order_items")

# %%
# 91

spark.sql("""
SELECT * FROM customers
""").show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          1|  Amit|Hyderabad| 28| 2023-01-10|
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          3| Rahul|   Mumbai| 29| 2023-03-14|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          5| Arjun|  Chennai| 27| 2023-05-11|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |          8|  Neha|    Delhi| 30| 2023-07-10|
# |          9| Divya|Bangalore| 26| 2023-07-15|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         13|Naveen|  Chennai| 28| 2023-09-01|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# |         15|Simran|Bangalore| 25| 2023-09-18|
# +-----------+------+---------+---+-----------+

# %%
# 92

spark.sql("""
SELECT * FROM customers
WHERE age > 30
""").show()
# Out:
# +-----------+------+---------+---+-----------+
# |customer_id|  name|     city|age|signup_date|
# +-----------+------+---------+---+-----------+
# |          2| Priya|Bangalore| 32| 2023-02-12|
# |          4| Sneha|    Delhi| 35| 2023-04-15|
# |          6| Meera|Hyderabad| 31| 2023-06-10|
# |          7| Karan|     Pune| 33| 2023-06-22|
# |         10|Vikram|   Mumbai| 40| 2023-08-01|
# |         11|  Ritu|Hyderabad| 34| 2023-08-10|
# |         12|Sanjay|    Delhi| 38| 2023-08-21|
# |         14|Farhan|   Mumbai| 36| 2023-09-10|
# +-----------+------+---------+---+-----------+

# %%
# 93

spark.sql("""
SELECT city, COUNT(*) AS customer_count
FROM customers
GROUP BY city
""").show()
# Out:
# +---------+--------------+
# |     city|customer_count|
# +---------+--------------+
# |Bangalore|             3|
# |  Chennai|             2|
# |   Mumbai|             3|
# |     Pune|             1|
# |    Delhi|             3|
# |Hyderabad|             3|
# +---------+--------------+

# %%
# 94

spark.sql("""
SELECT city, AVG(age) AS average_age
FROM customers
GROUP BY city
""").show()
# Out:
# +---------+------------------+
# |     city|       average_age|
# +---------+------------------+
# |Bangalore|27.666666666666668|
# |  Chennai|              27.5|
# |   Mumbai|              35.0|
# |     Pune|              33.0|
# |    Delhi|34.333333333333336|
# |Hyderabad|              31.0|
# +---------+------------------+

# %%
# 95

spark.sql("""
SELECT c.customer_id, c.name, c.city, o.order_id, o.order_date, o.status
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
""").show()
# Out:
# +-----------+------+---------+--------+----------+---------+
# |customer_id|  name|     city|order_id|order_date|   status|
# +-----------+------+---------+--------+----------+---------+
# |          1|  Amit|Hyderabad|       1|2024-03-01|Delivered|
# |          2| Priya|Bangalore|       2|2024-03-02|Delivered|
# |          3| Rahul|   Mumbai|       3|2024-03-03|Cancelled|
# |          4| Sneha|    Delhi|       4|2024-03-04|Delivered|
# |          5| Arjun|  Chennai|       5|2024-03-05|Delivered|
# |          6| Meera|Hyderabad|       6|2024-03-06|Delivered|
# |          7| Karan|     Pune|       7|2024-03-07|  Pending|
# |          8|  Neha|    Delhi|       8|2024-03-08|Delivered|
# |          9| Divya|Bangalore|       9|2024-03-09|Delivered|
# |         10|Vikram|   Mumbai|      10|2024-03-10|Delivered|
# +-----------+------+---------+--------+----------+---------+

# %%
# 96

spark.sql("""
SELECT c.name, COUNT(o.order_id) AS total_orders
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
GROUP BY c.name
""").show()
# Out:
# +------+------------+
# |  name|total_orders|
# +------+------------+
# | Divya|           1|
# | Meera|           1|
# | Sneha|           1|
# | Priya|           1|
# |Vikram|           1|
# | Rahul|           1|
# | Arjun|           1|
# |  Amit|           1|
# |  Neha|           1|
# | Karan|           1|
# +------+------------+

# %%
# 97

spark.sql("""
SELECT oi.order_id, p.product_name, p.category, oi.quantity, p.price
FROM order_items oi
JOIN products p
ON oi.product_id = p.product_id
""").show()
# Out:
# +--------+------------+-----------+--------+-----+
# |order_id|product_name|   category|quantity|price|
# +--------+------------+-----------+--------+-----+
# |       3|      Laptop|Electronics|       1|75000|
# |       1|      Laptop|Electronics|       1|75000|
# |       6|  Headphones|Electronics|       3| 3000|
# |       1|  Headphones|Electronics|       2| 3000|
# |       7|    Keyboard|Electronics|       2| 1500|
# |       2|    Keyboard|Electronics|       1| 1500|
# |       4|     Monitor|Electronics|       1|12000|
# |       5|  Smartphone|Electronics|       1|40000|
# |       9|    Notebook| Stationery|       5|  100|
# |      10|         Pen| Stationery|      10|   20|
# |       8|      Tablet|Electronics|       1|30000|
# +--------+------------+-----------+--------+-----+

# %%
# 98

spark.sql("""
SELECT
    oi.order_id,
    p.product_name,
    oi.quantity,
    p.price,
    oi.quantity * p.price AS revenue
FROM order_items oi
JOIN products p
ON oi.product_id = p.product_id
""").show()
# Out:
# +--------+------------+--------+-----+-------+
# |order_id|product_name|quantity|price|revenue|
# +--------+------------+--------+-----+-------+
# |       3|      Laptop|       1|75000|  75000|
# |       1|      Laptop|       1|75000|  75000|
# |       6|  Headphones|       3| 3000|   9000|
# |       1|  Headphones|       2| 3000|   6000|
# |       7|    Keyboard|       2| 1500|   3000|
# |       2|    Keyboard|       1| 1500|   1500|
# |       4|     Monitor|       1|12000|  12000|
# |       5|  Smartphone|       1|40000|  40000|
# |       9|    Notebook|       5|  100|    500|
# |      10|         Pen|      10|   20|    200|
# |       8|      Tablet|       1|30000|  30000|
# +--------+------------+--------+-----+-------+

# %%
# 99

spark.sql("""
SELECT
    c.name,
    SUM(oi.quantity * p.price) AS total_revenue
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
JOIN order_items oi
ON o.order_id = oi.order_id
JOIN products p
ON oi.product_id = p.product_id
GROUP BY c.name
ORDER BY total_revenue DESC
LIMIT 3
""").show()
# Out:
# +-----+-------------+
# | name|total_revenue|
# +-----+-------------+
# | Amit|        81000|
# |Rahul|        75000|
# |Arjun|        40000|
# +-----+-------------+

# %%
# 100

spark.sql("""
SELECT
    p.product_name,
    SUM(oi.quantity * p.price) AS total_revenue
FROM order_items oi
JOIN products p
ON oi.product_id = p.product_id
GROUP BY p.product_name
ORDER BY total_revenue DESC
LIMIT 1
""").show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |      Laptop|       150000|
# +------------+-------------+

# %% [markdown]
# **Final Capstone Mini Project**

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

# %%
# 1

final_df = orders.join(customers, "customer_id") \
                 .join(order_items, "order_id") \
                 .join(products, "product_id") \
                 .join(payments, "order_id")

final_df.show()
# Out:
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+
# |order_id|product_id|customer_id|order_date|   status|  name|     city|age|signup_date|quantity|product_name|   category|price|payment_id|payment_type|amount|
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+
# |       1|       102|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       2|  Headphones|Electronics| 3000|         1| Credit Card| 81000|
# |       1|       101|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       1|      Laptop|Electronics|75000|         1| Credit Card| 81000|
# |       2|       103|          2|2024-03-02|Delivered| Priya|Bangalore| 32| 2023-02-12|       1|    Keyboard|Electronics| 1500|         2|         UPI|  1500|
# |       3|       101|          3|2024-03-03|Cancelled| Rahul|   Mumbai| 29| 2023-03-14|       1|      Laptop|Electronics|75000|         3|  Debit Card| 75000|
# |       4|       104|          4|2024-03-04|Delivered| Sneha|    Delhi| 35| 2023-04-15|       1|     Monitor|Electronics|12000|         4| Credit Card| 12000|
# |       5|       107|          5|2024-03-05|Delivered| Arjun|  Chennai| 27| 2023-05-11|       1|  Smartphone|Electronics|40000|         5|         UPI| 40000|
# |       6|       102|          6|2024-03-06|Delivered| Meera|Hyderabad| 31| 2023-06-10|       3|  Headphones|Electronics| 3000|         6|         UPI|  9000|
# |       7|       103|          7|2024-03-07|  Pending| Karan|     Pune| 33| 2023-06-22|       2|    Keyboard|Electronics| 1500|         7|  Debit Card|  3000|
# |       8|       110|          8|2024-03-08|Delivered|  Neha|    Delhi| 30| 2023-07-10|       1|      Tablet|Electronics|30000|         8| Credit Card| 30000|
# |       9|       108|          9|2024-03-09|Delivered| Divya|Bangalore| 26| 2023-07-15|       5|    Notebook| Stationery|  100|         9|         UPI|   500|
# |      10|       109|         10|2024-03-10|Delivered|Vikram|   Mumbai| 40| 2023-08-01|      10|         Pen| Stationery|   20|        10|         UPI|   200|
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+

# %%
# 2

final_df = final_df.withColumn(
    "revenue",
    col("quantity") * col("price")
)

final_df.show()
# Out:
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+-------+
# |order_id|product_id|customer_id|order_date|   status|  name|     city|age|signup_date|quantity|product_name|   category|price|payment_id|payment_type|amount|revenue|
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+-------+
# |       1|       102|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       2|  Headphones|Electronics| 3000|         1| Credit Card| 81000|   6000|
# |       1|       101|          1|2024-03-01|Delivered|  Amit|Hyderabad| 28| 2023-01-10|       1|      Laptop|Electronics|75000|         1| Credit Card| 81000|  75000|
# |       2|       103|          2|2024-03-02|Delivered| Priya|Bangalore| 32| 2023-02-12|       1|    Keyboard|Electronics| 1500|         2|         UPI|  1500|   1500|
# |       3|       101|          3|2024-03-03|Cancelled| Rahul|   Mumbai| 29| 2023-03-14|       1|      Laptop|Electronics|75000|         3|  Debit Card| 75000|  75000|
# |       4|       104|          4|2024-03-04|Delivered| Sneha|    Delhi| 35| 2023-04-15|       1|     Monitor|Electronics|12000|         4| Credit Card| 12000|  12000|
# |       5|       107|          5|2024-03-05|Delivered| Arjun|  Chennai| 27| 2023-05-11|       1|  Smartphone|Electronics|40000|         5|         UPI| 40000|  40000|
# |       6|       102|          6|2024-03-06|Delivered| Meera|Hyderabad| 31| 2023-06-10|       3|  Headphones|Electronics| 3000|         6|         UPI|  9000|   9000|
# |       7|       103|          7|2024-03-07|  Pending| Karan|     Pune| 33| 2023-06-22|       2|    Keyboard|Electronics| 1500|         7|  Debit Card|  3000|   3000|
# |       8|       110|          8|2024-03-08|Delivered|  Neha|    Delhi| 30| 2023-07-10|       1|      Tablet|Electronics|30000|         8| Credit Card| 30000|  30000|
# |       9|       108|          9|2024-03-09|Delivered| Divya|Bangalore| 26| 2023-07-15|       5|    Notebook| Stationery|  100|         9|         UPI|   500|    500|
# |      10|       109|         10|2024-03-10|Delivered|Vikram|   Mumbai| 40| 2023-08-01|      10|         Pen| Stationery|   20|        10|         UPI|   200|    200|
# +--------+----------+-----------+----------+---------+------+---------+---+-----------+--------+------------+-----------+-----+----------+------------+------+-------+

# %%
# 3

top_customers = final_df.groupBy("name") \
                        .agg(sum("revenue").alias("total_revenue")) \
                        .orderBy(col("total_revenue").desc())

top_customers.show()
# Out:
# +------+-------------+
# |  name|total_revenue|
# +------+-------------+
# |  Amit|        81000|
# | Rahul|        75000|
# | Arjun|        40000|
# |  Neha|        30000|
# | Sneha|        12000|
# | Meera|         9000|
# | Karan|         3000|
# | Priya|         1500|
# | Divya|          500|
# |Vikram|          200|
# +------+-------------+

# %%
# 4

top_products = final_df.groupBy("product_name") \
                       .agg(sum("revenue").alias("total_revenue")) \
                       .orderBy(col("total_revenue").desc())

top_products.show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |      Laptop|       150000|
# |  Smartphone|        40000|
# |      Tablet|        30000|
# |  Headphones|        15000|
# |     Monitor|        12000|
# |    Keyboard|         4500|
# |    Notebook|          500|
# |         Pen|          200|
# +------------+-------------+

# %%
# 5
revenue_per_city = final_df.groupBy("city") \
                           .agg(sum("revenue").alias("city_revenue")) \
                           .orderBy(col("city_revenue").desc())

revenue_per_city.show()
# Out:
# +---------+------------+
# |     city|city_revenue|
# +---------+------------+
# |Hyderabad|       90000|
# |   Mumbai|       75200|
# |    Delhi|       42000|
# |  Chennai|       40000|
# |     Pune|        3000|
# |Bangalore|        2000|
# +---------+------------+

# %%
# 6

rank_window = Window.orderBy(col("total_revenue").desc())

ranked_customers = top_customers.withColumn(
    "rank",
    rank().over(rank_window)
)

ranked_customers.show()
# Out:
# +------+-------------+----+
# |  name|total_revenue|rank|
# +------+-------------+----+
# |  Amit|        81000|   1|
# | Rahul|        75000|   2|
# | Arjun|        40000|   3|
# |  Neha|        30000|   4|
# | Sneha|        12000|   5|
# | Meera|         9000|   6|
# | Karan|         3000|   7|
# | Priya|         1500|   8|
# | Divya|          500|   9|
# |Vikram|          200|  10|
# +------+-------------+----+

# %%
# 7

final_df.write.mode("overwrite").csv("ecommerce_report", header=True)

# %%
# !ls
# Out:
# customers.csv	  logs.txt	   orders.csv	 products.csv
# ecommerce_report  order_items.csv  payments.csv  sample_data
